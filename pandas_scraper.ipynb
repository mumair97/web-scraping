# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Demographics_of_Pakistan"

# %%
df = pd.read_html(url)

# %%
len(df) ## 33 tables
# Out:
# 33

# %%
df[10] ## df[10]  => 10th table
# Out:
#     Year Mid-year population Annual live births Annual deaths  \
#     Year Mid-year population Annual live births Annual deaths
# 0   1950            37696264            1647739       1173219
# 1   1951            38215785            1686378       1121858
# 2   1952            38816777            1727288       1089817
# 3   1953            39488228            1768524       1063098
# 4   1954            40224090            1810574       1044277
# ..   ...                 ...                ...           ...
# 67  2017           216379655            6289965       1496276
# 68  2018           219731479            6302081       1508129
# 69  2019           223293280            6330933       1514600
# 70  2020           227196741            6362705       1606293
# 71  2021           231402117            6374741       1660400
#
#    Annual natural increase   CBR   CDR   RNC    IMR   TFR Life expectancy  \
#    Annual natural increase   CBR   CDR   RNC    IMR   TFR            Male
# ...

# %%
df[16] ## countries list
# Out:
#                        0            1
# 0           Saudi Arabia      4000000
# 1   United Arab Emirates      1600000
# 2         United Kingdom      1200000
# 3          United States  600,410[97]
# 4                 Canada  215,000[98]
# 5                 Kuwait       190000
# 6           South Africa  180,000[99]
# 7                   Oman       385000
# 8              Australia  61,913[100]
# 9                Germany       179668
# 10                 Qatar        52500
# 11                France        50000
# 12                Norway  39,257[101]
# 13               Denmark        21000
# 14           New Zealand        10000
# 15               Ireland         9501

# %%
## import into csv
df[16].to_csv("countries_list.csv", index=False)

# %% [markdown]
# ## Assignment
# website = worlddata.info
#
# I saved only table at index 16, but now
#
# save all the tables in one CSV file
